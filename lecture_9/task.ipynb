# %%
from enum import StrEnum
import random
from typing import Self
from rich import print as rich_print

# %%
class Names(StrEnum):
  JOHN: str = "John"
  PAUL: str = "Paul"
  GEORGE: str = "George"

class Beatle:
  
  def __init__(self, name: Names = Names.JOHN, health_points: int = 100) -> None:
    self.name = name
    self.health_points = health_points
    
  def __eq__(self: Self, other: Self) -> bool:
    return self.health_points == other.health_points

  def __lt__(self: Self, other: Self) -> bool:
    return self.health_points < other.health_points
  
  def __le__(self: Self, other: Self) -> bool:
    return self.health_points <= other.health_points
  
  def __str__(self: Self) -> str:
    return f"Beatle: name={self.name!r}, health_points={self.health_points!r}"
  
  def attack(self: Self, target: Self, max_damage: int) -> Self:
    if target.health_points > 0:
      target.health_points -= random.randint(1, max_damage)
      rich_print(f"[bold blue]{self.name} attacked {target.name} and reduced their health to {target.health_points}")
      return target
    
  def add_health(self: Self, health: int, max_hp: int) -> None:
    self.health_points = min(self.health_points + health, max_hp)
  
      
class BeetleArmy:
  beetles_list: list[Beatle]
  beetles_name: Names
  beatles_max_health_points: int
  beatles_max_damage: int
  
  def __init__(self: Self, beatles_name: Names, beetles_army_size: int = 20, beetles_max_health_points: int = 100, beatles_max_damage: int = 15) -> None:
    self.beetles_name = beatles_name
    self.beatles_max_health_points = beetles_max_health_points
    self.beatles_max_damage = beatles_max_damage
    self.beetles_list = []
    
    for _ in range(beetles_army_size):
      beetle: Beatle = Beatle(name=self.beetles_name, health_points=random.randint(a=1, b=self.beatles_max_health_points))
      self.beetles_list.append(beetle)
      
  def __len__(self: Self) -> int: 
    return len(self.beetles_list)
  
  @property
  def army_health(self: Self) -> int:
    return sum([beatle.health_points for beatle in self.beetles_list])
  
  def __lt__(self: Self, other: Self) -> bool:
    return self.army_health < other.army_health
  
  def __le__(self: Self, other: Self) -> bool:
    return self.army_health <= other.army_health
  
  def __eq__(self: Self, other: Self) -> bool:
    return self.army_health == other.army_health

  def __add__(self: Self, other: Self) -> Self:
    if self.beetles_name != other.beetles_name:
      raise ValueError("Invalid provided value: Different beetles names")
    new_list: list[Beatle] = self.beetles_list + other.beetles_list
    
    new_army = self.__class__(
      beatles_name = self.beetles_name,
      beetles_army_size = len(new_list),
      beetles_max_health_points = self.beatles_max_health_points
    )      
    
    new_army.beetles_list = new_list
    
    return new_army
  
  def fight_beatles(self: Self, list_1: list[Beatle], list_2: list[Beatle]) -> tuple[list[Beatle], list[Beatle]]:
    
    beatles_damaged = []
    
    for i in range(min(len(list_1), len(list_2))):
      
      damaged_beatle = list_1[i].attack(list_2[i], self.beatles_max_damage)
      
      if damaged_beatle.health_points > 0:
        beatles_damaged.append(damaged_beatle)
      else:
        list_1[i].add_health(10, self.beatles_max_health_points)
        rich_print(f"[italic red]Beatle died in the fight, beatle name: {damaged_beatle.name}, index: {i}")
    
    return beatles_damaged, list_2
    
  
  def battle(self: Self, other: Self):
    self_beatles_army = self.beetles_list.copy()
    other_beatles_army = other.beetles_list.copy()
    round_num = 0
    
    while self_beatles_army and other_beatles_army:
      round_num += 1
      rich_print(f"[bold cyan]Round {round_num}:")
      
      (self_beatles_army, other_beatles_army) = self.fight_beatles(self_beatles_army, other_beatles_army)
      (other_beatles_army, self_beatles_army) = self.fight_beatles(other_beatles_army, self_beatles_army)
      
      rich_print(f"  {self.beetles_name} army: {len(self_beatles_army)} beetles, total HP: {sum(b.health_points for b in self_beatles_army)}")
      rich_print(f"  {other.beetles_name} army: {len(other_beatles_army)} beetles, total HP: {sum(b.health_points for b in other_beatles_army)}")
      rich_print()
    
    winner = self.beetles_name if self_beatles_army else other.beetles_name
    rich_print(f"[green bold]Army {winner} wins after {round_num} rounds!")        
    
      
  def print_army_listing(self: Self) -> None:
    for beetle in self.beetles_list:
      print(beetle)

# %%
print("Enter details for Army 1:")
army1_name = input("Name (JOHN, PAUL, GEORGE): ").upper()
army1_size = int(input("Army size: "))
army1_max_hp = int(input("Max health points: "))
army1_max_damage = int(input("Max damage: "))

print("\nEnter details for Army 2:")
army2_name = input("Name (JOHN, PAUL, GEORGE): ").upper()
army2_size = int(input("Army size: "))
army2_max_hp = int(input("Max health points: "))
army2_max_damage = int(input("Max damage: "))

army_1 = BeetleArmy(beatles_name=Names[army1_name], beetles_army_size=army1_size, beetles_max_health_points=army1_max_hp, beatles_max_damage=army1_max_damage)
army_2 = BeetleArmy(beatles_name=Names[army2_name], beetles_army_size=army2_size, beetles_max_health_points=army2_max_hp, beatles_max_damage=army2_max_damage)

rich_print(f"[bold green]Army 1: {army_1.beetles_name}")
army_1.print_army_listing()
rich_print(f"[bold green]Army 2: {army_2.beetles_name}")
army_2.print_army_listing()

rich_print("[bold yellow]Starting battle...")
army_1.battle(army_2)
# Out:
# Enter details for Army 1:
#
# Enter details for Army 2:
# Army 1: John
# Beatle: name=<Names.JOHN: 'John'>, health_points=55
# Beatle: name=<Names.JOHN: 'John'>, health_points=42
# Beatle: name=<Names.JOHN: 'John'>, health_points=20
# Beatle: name=<Names.JOHN: 'John'>, health_points=10
# Beatle: name=<Names.JOHN: 'John'>, health_points=84
# Beatle: name=<Names.JOHN: 'John'>, health_points=81
# Beatle: name=<Names.JOHN: 'John'>, health_points=98
# Beatle: name=<Names.JOHN: 'John'>, health_points=95
# Beatle: name=<Names.JOHN: 'John'>, health_points=57
# Beatle: name=<Names.JOHN: 'John'>, health_points=100
# Beatle: name=<Names.JOHN: 'John'>, health_points=38
# Beatle: name=<Names.JOHN: 'John'>, health_points=55
# Beatle: name=<Names.JOHN: 'John'>, health_points=9
# Beatle: name=<Names.JOHN: 'John'>, health_points=13
# Beatle: name=<Names.JOHN: 'John'>, health_points=58
# Beatle: name=<Names.JOHN: 'John'>, health_points=39
# Beatle: name=<Names.JOHN: 'John'>, health_points=9
# Beatle: name=<Names.JOHN: 'John'>, health_points=77
# Beatle: name=<Names.JOHN: 'John'>, health_points=56
# Beatle: name=<Names.JOHN: 'John'>, health_points=12
# Beatle: name=<Names.JOHN: 'John'>, health_points=7
# Beatle: name=<Names.JOHN: 'John'>, health_points=98
# Beatle: name=<Names.JOHN: 'John'>, health_points=8
# Beatle: name=<Names.JOHN: 'John'>, health_points=39
# Beatle: name=<Names.JOHN: 'John'>, health_points=49
# Beatle: name=<Names.JOHN: 'John'>, health_points=5
# Beatle: name=<Names.JOHN: 'John'>, health_points=64
# Beatle: name=<Names.JOHN: 'John'>, health_points=50
# Beatle: name=<Names.JOHN: 'John'>, health_points=22
# Beatle: name=<Names.JOHN: 'John'>, health_points=79
# Beatle: name=<Names.JOHN: 'John'>, health_points=84
# Beatle: name=<Names.JOHN: 'John'>, health_points=60
# Beatle: name=<Names.JOHN: 'John'>, health_points=10
# Beatle: name=<Names.JOHN: 'John'>, health_points=51
# Beatle: name=<Names.JOHN: 'John'>, health_points=10
# Beatle: name=<Names.JOHN: 'John'>, health_points=21
# Beatle: name=<Names.JOHN: 'John'>, health_points=36
# Beatle: name=<Names.JOHN: 'John'>, health_points=31
# Beatle: name=<Names.JOHN: 'John'>, health_points=61
# Beatle: name=<Names.JOHN: 'John'>, health_points=18
# Beatle: name=<Names.JOHN: 'John'>, health_points=26
# Beatle: name=<Names.JOHN: 'John'>, health_points=29
# Beatle: name=<Names.JOHN: 'John'>, health_points=93
# Beatle: name=<Names.JOHN: 'John'>, health_points=9
# Beatle: name=<Names.JOHN: 'John'>, health_points=14
# Beatle: name=<Names.JOHN: 'John'>, health_points=80
# Beatle: name=<Names.JOHN: 'John'>, health_points=53
# Beatle: name=<Names.JOHN: 'John'>, health_points=18
# Beatle: name=<Names.JOHN: 'John'>, health_points=82
# Beatle: name=<Names.JOHN: 'John'>, health_points=81
# Beatle: name=<Names.JOHN: 'John'>, health_points=41
# Beatle: name=<Names.JOHN: 'John'>, health_points=38
# Beatle: name=<Names.JOHN: 'John'>, health_points=52
# Beatle: name=<Names.JOHN: 'John'>, health_points=66
# Beatle: name=<Names.JOHN: 'John'>, health_points=50
# Beatle: name=<Names.JOHN: 'John'>, health_points=25
# Beatle: name=<Names.JOHN: 'John'>, health_points=46
# Beatle: name=<Names.JOHN: 'John'>, health_points=77
# Beatle: name=<Names.JOHN: 'John'>, health_points=70
# Beatle: name=<Names.JOHN: 'John'>, health_points=11
# Beatle: name=<Names.JOHN: 'John'>, health_points=75
# Beatle: name=<Names.JOHN: 'John'>, health_points=62
# Beatle: name=<Names.JOHN: 'John'>, health_points=38
# Beatle: name=<Names.JOHN: 'John'>, health_points=90
# Beatle: name=<Names.JOHN: 'John'>, health_points=26
# Beatle: name=<Names.JOHN: 'John'>, health_points=15
# Beatle: name=<Names.JOHN: 'John'>, health_points=41
# Beatle: name=<Names.JOHN: 'John'>, health_points=34
# Beatle: name=<Names.JOHN: 'John'>, health_points=48
# Beatle: name=<Names.JOHN: 'John'>, health_points=90
# Beatle: name=<Names.JOHN: 'John'>, health_points=16
# Beatle: name=<Names.JOHN: 'John'>, health_points=45
# Beatle: name=<Names.JOHN: 'John'>, health_points=97
# Beatle: name=<Names.JOHN: 'John'>, health_points=88
# Beatle: name=<Names.JOHN: 'John'>, health_points=36
# Beatle: name=<Names.JOHN: 'John'>, health_points=33
# Beatle: name=<Names.JOHN: 'John'>, health_points=71
# Beatle: name=<Names.JOHN: 'John'>, health_points=82
# Beatle: name=<Names.JOHN: 'John'>, health_points=85
# Beatle: name=<Names.JOHN: 'John'>, health_points=23
# Beatle: name=<Names.JOHN: 'John'>, health_points=74
# Beatle: name=<Names.JOHN: 'John'>, health_points=84
# Beatle: name=<Names.JOHN: 'John'>, health_points=69
# Beatle: name=<Names.JOHN: 'John'>, health_points=51
# Beatle: name=<Names.JOHN: 'John'>, health_points=72
# Beatle: name=<Names.JOHN: 'John'>, health_points=77
# Beatle: name=<Names.JOHN: 'John'>, health_points=83
# Beatle: name=<Names.JOHN: 'John'>, health_points=67
# Beatle: name=<Names.JOHN: 'John'>, health_points=38
# Beatle: name=<Names.JOHN: 'John'>, health_points=64
# Beatle: name=<Names.JOHN: 'John'>, health_points=80
# Beatle: name=<Names.JOHN: 'John'>, health_points=53
# Beatle: name=<Names.JOHN: 'John'>, health_points=74
# Beatle: name=<Names.JOHN: 'John'>, health_points=26
# Beatle: name=<Names.JOHN: 'John'>, health_points=78
# Beatle: name=<Names.JOHN: 'John'>, health_points=47
# Beatle: name=<Names.JOHN: 'John'>, health_points=88
# Beatle: name=<Names.JOHN: 'John'>, health_points=49
# Beatle: name=<Names.JOHN: 'John'>, health_points=23
# Beatle: name=<Names.JOHN: 'John'>, health_points=4
# Army 2: George
# Beatle: name=<Names.GEORGE: 'George'>, health_points=37
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=11
# Beatle: name=<Names.GEORGE: 'George'>, health_points=73
# Beatle: name=<Names.GEORGE: 'George'>, health_points=51
# Beatle: name=<Names.GEORGE: 'George'>, health_points=66
# Beatle: name=<Names.GEORGE: 'George'>, health_points=24
# Beatle: name=<Names.GEORGE: 'George'>, health_points=61
# Beatle: name=<Names.GEORGE: 'George'>, health_points=35
# Beatle: name=<Names.GEORGE: 'George'>, health_points=45
# Beatle: name=<Names.GEORGE: 'George'>, health_points=48
# Beatle: name=<Names.GEORGE: 'George'>, health_points=36
# Beatle: name=<Names.GEORGE: 'George'>, health_points=53
# Beatle: name=<Names.GEORGE: 'George'>, health_points=41
# Beatle: name=<Names.GEORGE: 'George'>, health_points=26
# Beatle: name=<Names.GEORGE: 'George'>, health_points=74
# Beatle: name=<Names.GEORGE: 'George'>, health_points=65
# Beatle: name=<Names.GEORGE: 'George'>, health_points=73
# Beatle: name=<Names.GEORGE: 'George'>, health_points=9
# Beatle: name=<Names.GEORGE: 'George'>, health_points=10
# Beatle: name=<Names.GEORGE: 'George'>, health_points=15
# Beatle: name=<Names.GEORGE: 'George'>, health_points=41
# Beatle: name=<Names.GEORGE: 'George'>, health_points=41
# Beatle: name=<Names.GEORGE: 'George'>, health_points=77
# Beatle: name=<Names.GEORGE: 'George'>, health_points=59
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=70
# Beatle: name=<Names.GEORGE: 'George'>, health_points=7
# Beatle: name=<Names.GEORGE: 'George'>, health_points=51
# Beatle: name=<Names.GEORGE: 'George'>, health_points=42
# Beatle: name=<Names.GEORGE: 'George'>, health_points=13
# Beatle: name=<Names.GEORGE: 'George'>, health_points=61
# Beatle: name=<Names.GEORGE: 'George'>, health_points=48
# Beatle: name=<Names.GEORGE: 'George'>, health_points=45
# Beatle: name=<Names.GEORGE: 'George'>, health_points=11
# Beatle: name=<Names.GEORGE: 'George'>, health_points=58
# Beatle: name=<Names.GEORGE: 'George'>, health_points=28
# Beatle: name=<Names.GEORGE: 'George'>, health_points=47
# Beatle: name=<Names.GEORGE: 'George'>, health_points=75
# Beatle: name=<Names.GEORGE: 'George'>, health_points=32
# Beatle: name=<Names.GEORGE: 'George'>, health_points=50
# Beatle: name=<Names.GEORGE: 'George'>, health_points=26
# Beatle: name=<Names.GEORGE: 'George'>, health_points=65
# Beatle: name=<Names.GEORGE: 'George'>, health_points=26
# Beatle: name=<Names.GEORGE: 'George'>, health_points=40
# Beatle: name=<Names.GEORGE: 'George'>, health_points=80
# Beatle: name=<Names.GEORGE: 'George'>, health_points=14
# Beatle: name=<Names.GEORGE: 'George'>, health_points=23
# Beatle: name=<Names.GEORGE: 'George'>, health_points=39
# Beatle: name=<Names.GEORGE: 'George'>, health_points=29
# Beatle: name=<Names.GEORGE: 'George'>, health_points=26
# Beatle: name=<Names.GEORGE: 'George'>, health_points=34
# Beatle: name=<Names.GEORGE: 'George'>, health_points=62
# Beatle: name=<Names.GEORGE: 'George'>, health_points=41
# Beatle: name=<Names.GEORGE: 'George'>, health_points=73
# Beatle: name=<Names.GEORGE: 'George'>, health_points=73
# Beatle: name=<Names.GEORGE: 'George'>, health_points=22
# Beatle: name=<Names.GEORGE: 'George'>, health_points=15
# Beatle: name=<Names.GEORGE: 'George'>, health_points=9
# Beatle: name=<Names.GEORGE: 'George'>, health_points=79
# Beatle: name=<Names.GEORGE: 'George'>, health_points=50
# Beatle: name=<Names.GEORGE: 'George'>, health_points=63
# Beatle: name=<Names.GEORGE: 'George'>, health_points=72
# Beatle: name=<Names.GEORGE: 'George'>, health_points=47
# Beatle: name=<Names.GEORGE: 'George'>, health_points=72
# Beatle: name=<Names.GEORGE: 'George'>, health_points=57
# Beatle: name=<Names.GEORGE: 'George'>, health_points=5
# Beatle: name=<Names.GEORGE: 'George'>, health_points=14
# Beatle: name=<Names.GEORGE: 'George'>, health_points=31
# Beatle: name=<Names.GEORGE: 'George'>, health_points=9
# Beatle: name=<Names.GEORGE: 'George'>, health_points=54
# Beatle: name=<Names.GEORGE: 'George'>, health_points=30
# Beatle: name=<Names.GEORGE: 'George'>, health_points=54
# Beatle: name=<Names.GEORGE: 'George'>, health_points=7
# Beatle: name=<Names.GEORGE: 'George'>, health_points=58
# Beatle: name=<Names.GEORGE: 'George'>, health_points=17
# Beatle: name=<Names.GEORGE: 'George'>, health_points=77
# Beatle: name=<Names.GEORGE: 'George'>, health_points=80
# Beatle: name=<Names.GEORGE: 'George'>, health_points=80
# Beatle: name=<Names.GEORGE: 'George'>, health_points=23
# Beatle: name=<Names.GEORGE: 'George'>, health_points=12
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=56
# Beatle: name=<Names.GEORGE: 'George'>, health_points=62
# Beatle: name=<Names.GEORGE: 'George'>, health_points=75
# Beatle: name=<Names.GEORGE: 'George'>, health_points=70
# Beatle: name=<Names.GEORGE: 'George'>, health_points=4
# Beatle: name=<Names.GEORGE: 'George'>, health_points=60
# Beatle: name=<Names.GEORGE: 'George'>, health_points=3
# Beatle: name=<Names.GEORGE: 'George'>, health_points=35
# Beatle: name=<Names.GEORGE: 'George'>, health_points=22
# Beatle: name=<Names.GEORGE: 'George'>, health_points=57
# Beatle: name=<Names.GEORGE: 'George'>, health_points=50
# Beatle: name=<Names.GEORGE: 'George'>, health_points=67
# Beatle: name=<Names.GEORGE: 'George'>, health_points=68
# Beatle: name=<Names.GEORGE: 'George'>, health_points=19
# Beatle: name=<Names.GEORGE: 'George'>, health_points=5
# Beatle: name=<Names.GEORGE: 'George'>, health_points=71
# Beatle: name=<Names.GEORGE: 'George'>, health_points=23
# Beatle: name=<Names.GEORGE: 'George'>, health_points=60
# Beatle: name=<Names.GEORGE: 'George'>, health_points=73
# Beatle: name=<Names.GEORGE: 'George'>, health_points=17
# Beatle: name=<Names.GEORGE: 'George'>, health_points=57
# Beatle: name=<Names.GEORGE: 'George'>, health_points=61
# Beatle: name=<Names.GEORGE: 'George'>, health_points=78
# Beatle: name=<Names.GEORGE: 'George'>, health_points=44
# Beatle: name=<Names.GEORGE: 'George'>, health_points=8
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=60
# Beatle: name=<Names.GEORGE: 'George'>, health_points=69
# Beatle: name=<Names.GEORGE: 'George'>, health_points=28
# Beatle: name=<Names.GEORGE: 'George'>, health_points=31
# Beatle: name=<Names.GEORGE: 'George'>, health_points=40
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=53
# Beatle: name=<Names.GEORGE: 'George'>, health_points=19
# Beatle: name=<Names.GEORGE: 'George'>, health_points=64
# Beatle: name=<Names.GEORGE: 'George'>, health_points=48
# Beatle: name=<Names.GEORGE: 'George'>, health_points=27
# Beatle: name=<Names.GEORGE: 'George'>, health_points=44
# Starting battle...
# Round 1:
# John attacked George and reduced their health to 15
# John attacked George and reduced their health to 14
# John attacked George and reduced their health to 8
# John attacked George and reduced their health to 64
# John attacked George and reduced their health to 39
# John attacked George and reduced their health to 53
# John attacked George and reduced their health to 1
# John attacked George and reduced their health to 46
# John attacked George and reduced their health to 25
# John attacked George and reduced their health to 26
# John attacked George and reduced their health to 36
# John attacked George and reduced their health to 21
# John attacked George and reduced their health to 43
# John attacked George and reduced their health to 19
# John attacked George and reduced their health to 5
# John attacked George and reduced their health to 50
# John attacked George and reduced their health to 43
# John attacked George and reduced their health to 68
# John attacked George and reduced their health to -11
# Beatle died in the fight, beatle name: George, index: 18
# John attacked George and reduced their health to 3
# John attacked George and reduced their health to 13
# John attacked George and reduced their health to 17
# John attacked George and reduced their health to 29
# John attacked George and reduced their health to 66
# John attacked George and reduced their health to 49
# John attacked George and reduced their health to 26
# John attacked George and reduced their health to 51
# John attacked George and reduced their health to 1
# John attacked George and reduced their health to 38
# John attacked George and reduced their health to 25
# John attacked George and reduced their health to 6
# John attacked George and reduced their health to 50
# John attacked George and reduced their health to 24
# John attacked George and reduced their health to 21
# John attacked George and reduced their health to -2
# Beatle died in the fight, beatle name: George, index: 34
# John attacked George and reduced their health to 35
# John attacked George and reduced their health to 5
# John attacked George and reduced their health to 25
# John attacked George and reduced their health to 57
# John attacked George and reduced their health to 13
# John attacked George and reduced their health to 39
# John attacked George and reduced their health to 5
# John attacked George and reduced their health to 63
# John attacked George and reduced their health to 25
# John attacked George and reduced their health to 36
# John attacked George and reduced their health to 56
# John attacked George and reduced their health to 5
# John attacked George and reduced their health to 8
# John attacked George and reduced their health to 14
# John attacked George and reduced their health to 18
# John attacked George and reduced their health to 3
# John attacked George and reduced their health to 17
# John attacked George and reduced their health to 42
# John attacked George and reduced their health to 40
# John attacked George and reduced their health to 52
# John attacked George and reduced their health to 54
# John attacked George and reduced their health to 11
# John attacked George and reduced their health to 3
# John attacked George and reduced their health to -4
# Beatle died in the fight, beatle name: George, index: 58
# John attacked George and reduced their health to 76
# John attacked George and reduced their health to 28
# John attacked George and reduced their health to 60
