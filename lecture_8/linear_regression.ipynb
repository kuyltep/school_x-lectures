# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
dob_array = np.array([1990,1992,1994,1996,1998,2000,2002,2004])

# %%
plt.plot(dob_array)
